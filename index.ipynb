# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Read API Documentation
# * Translate documentation into Python code
# * Execute get requests in order to utilize the Yelp API
#
# Start by navigating to: https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
# As a reminder, we have:

# %%
import requests

# %%
url = ''
#This will be our next step
header = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, header=header)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-a01056aedb09> in <module>()
#       1 url = ''
#       2 #This will be our next step
# ----> 3 header = {"Authorization" : "Bearer {}".format(api_key)}
#       4 response = requests.get(url, header=header)
#
# NameError: name 'api_key' is not defined

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the url we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
#Note: this cell won't return a valid response unless you specify your api key
api_key = #put your api key (as a string) here
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
#Note: this cell won't return a valid response unless you specify your api key
api_key = '-qRE1pkKuBjYIIgE2bNYJK_Juato88GXHSZjzONJE1YbUnhqf2D6cbmf90vZvhx0N2mx3hPt2-yMUT__1OAQ6Tw09rV-OUq_RSJnG7QI-ziuD1wssqyQOvFQRWfcXHYx'

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
pizza = response.json()

# %%
pizza['businesses']['0']
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 2746,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7229087705545,
#    'longitude': -73.9944863319397},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1941.9638172538225},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 5843,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 1798.9959778083735},
#  {'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 416,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 3145.016041338447},
#  {'id': '2ggi1luerd3Mf_C82JvCYg',
#   'alias': 'grimaldis-pizzeria-brooklyn-4',
#   'name': "Grimaldi's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNKqW31PTvtSw6-Lbc1mtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 4476,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.70257, 'longitude': -73.99323},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188584300',
#   'display_phone': '(718) 858-4300',
#   'distance': 327.45636528596714},
#  {'id': 'ZTsN8TdMXl8SW_AKd_ablw',
#   'alias': 'forno-rosso-downtown-brooklyn-2',
#   'name': 'Forno Rosso',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9aKNymymd9out1HSpkLuiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/forno-rosso-downtown-brooklyn-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 602,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69446, 'longitude': -73.98316},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '327 Gold St',
#    'address2': '',
#    'address3': '',
#    'city': 'Downtown Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['327 Gold St', 'Downtown Brooklyn, NY 11201']},
#   'phone': '+17184513800',
#   'display_phone': '(718) 451-3800',
#   'distance': 1547.8879856668632},
#  {'id': 'uc5qQMzs96rzjK27epDCug',
#   'alias': 'joes-pizza-new-york-4',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FhbFkrh_3TrAOZvoWTyOJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 2246,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7305599, 'longitude': -74.0021299},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '7 Carmine St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7 Carmine St', 'New York, NY 10014']},
#   'phone': '+12123661182',
#   'display_phone': '(212) 366-1182',
#   'distance': 2873.5532231399425},
#  {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#   'alias': 'bleecker-street-pizza-new-york',
#   'name': 'Bleecker Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 2054,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7320627016512,
#    'longitude': -74.0036552270137},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '69 7th Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#   'phone': '+12129244466',
#   'display_phone': '(212) 924-4466',
#   'distance': 3072.9540450669765},
#  {'id': 'yH6t1JWcwkdWG4CS5KPvow',
#   'alias': 'adriennes-pizzabar-new-york',
#   'name': "Adrienne's Pizzabar",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOG8wpqkeYQxDslq7ospLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 1540,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7043362, 'longitude': -74.0101733},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '54 Stone St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['54 Stone St', 'New York, NY 10004']},
#   'phone': '+12122483838',
#   'display_phone': '(212) 248-3838',
#   'distance': 1344.2671600758972},
#  {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#   'alias': 'johns-of-bleecker-street-new-york-2',
#   'name': "John's of Bleecker Street",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ey_5ReYpouWm4SlY2DsaVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 1800,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '278 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12122431680',
#   'display_phone': '(212) 243-1680',
#   'distance': 3010.899021476809},
#  {'id': 'xxgcU_oFIox_pAmroo9WwA',
#   'alias': 'front-street-pizza-brooklyn',
#   'name': 'Front Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gefrnHNBSjOoa3PKvag9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/front-street-pizza-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 300,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70244, 'longitude': -73.98943},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '80 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188753700',
#   'display_phone': '(718) 875-3700',
#   'distance': 530.2856895611},
#  {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#   'alias': 'di-fara-pizza-brooklyn',
#   'name': 'Di Fara Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 3248,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1424 Ave J',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11230',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#   'phone': '+17182581367',
#   'display_phone': '(718) 258-1367',
#   'distance': 9352.269072867253},
#  {'id': 'i_rg-OLXQbpRUN7O3MeCeA',
#   'alias': 'piz-zetta-brooklyn-2',
#   'name': 'Piz-zetta',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9L4viDwAGx3obgYLnXMA6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piz-zetta-brooklyn-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 245,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6912834070746,
#    'longitude': -73.9906029201042},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '90 Livingston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#   'phone': '+17184227878',
#   'display_phone': '(718) 422-7878',
#   'distance': 1605.1176697811002},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xRNPKIfF2Gr02zBiBl3dSA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 2642,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.705043534338, 'longitude': -73.93357123374},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 5118.690592147886},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 1897,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 1931.2683716470422},
#  {'id': 'S4uozcDEieoaXxIJ6TsUoQ',
#   'alias': 'dellaroccos-brick-oven-pizza-brooklyn',
#   'name': "Dellarocco's Brick Oven Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2vQXryVUbOrXfYBkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dellaroccos-brick-oven-pizza-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 237,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6950309, 'longitude': -73.9961252},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '214 Hicks St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#   'phone': '+17188581010',
#   'display_phone': '(718) 858-1010',
#   'distance': 1170.2700329972115},
#  {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#   'alias': 'scarrs-pizza-new-york',
#   'name': "Scarr's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k3iXzXNevY7-CuIbE0-FaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 233,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '22 Orchard St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['22 Orchard St', 'New York, NY 10002']},
#   'phone': '+12123343481',
#   'display_phone': '(212) 334-3481',
#   'distance': 1125.7843300426755},
#  {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#   'alias': 'joes-pizza-new-york-7',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 775,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.733692, 'longitude': -73.988123},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '150 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 E 14th St', 'New York, NY 10003']},
#   'phone': '+12123889474',
#   'display_phone': '(212) 388-9474',
#   'distance': 3183.688184836435},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zFqYcj13GBxvXQ4oRUGgsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 250,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71691, 'longitude': -73.958987},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 3239.2966565668607},
#  {'id': 'atbANdSznV29GI066I2Ijw',
#   'alias': 'champion-pizza-new-york-6',
#   'name': 'Champion Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SV5N-uxEa1tHUXYLAi43xA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 251,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7215270996094,
#    'longitude': -73.9970855712891},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '17 Cleveland Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#   'phone': '+12122263777',
#   'display_phone': '(212) 226-3777',
#   'distance': 1801.4764439408825},
#  {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#   'alias': 'ny-pizza-suprema-new-york',
#   'name': 'NY Pizza Suprema',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 1784,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7502059936523,
#    'longitude': -73.9953231811523},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'phone': '+12125948939',
#   'display_phone': '(212) 594-8939',
#   'distance': 4977.847939164096},
#  {'id': 'B1XdGwZZ5ee2fBdngj7NUw',
#   'alias': 'underground-pizza-new-york',
#   'name': 'Underground Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gCOE3o5WufGPCaJcin5nNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/underground-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 271,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70499, 'longitude': -74.00961},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '3 Hanover Sq',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Hanover Sq', 'New York, NY 10004']},
#   'phone': '+12124254442',
#   'display_phone': '(212) 425-4442',
#   'distance': 1295.7652741508907},
#  {'id': 'MeQU-nGaQvX12VXYOyzavQ',
#   'alias': 'gruppo-new-york-4',
#   'name': 'Gruppo',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O7OTQ9v4Zil2-oykg9NI8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gruppo-new-york-4?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 240,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '98 Ave B',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['98 Ave B', 'New York, NY 10009']},
#   'phone': '+12129952100',
#   'display_phone': '(212) 995-2100',
#   'distance': 2395.292393078858},
#  {'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#   'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#   'name': 'Luzzos La Pizza Napoletana',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/siQq0MnFSCXmAd8rg28EwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 1011,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.730551, 'longitude': -73.9834846},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '211 1st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['211 1st Ave', 'New York, NY 10003']},
#   'phone': '+12124737447',
#   'display_phone': '(212) 473-7447',
#   'distance': 2936.5316530282876},
#  {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#   'alias': 'la-margarita-pizzeria-new-york',
#   'name': 'La Margarita Pizzeria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-margarita-pizzeria-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 266,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7215392420787,
#    'longitude': -73.9876275438289},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '168 Ludlow St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#   'phone': '+19172614983',
#   'display_phone': '(917) 261-4983',
#   'distance': 1875.7222956933838},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5P5i2QZhxCen55PNdU_TTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 628,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7545841255557,
#    'longitude': -73.9870039190341},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 5498.444221355099},
#  {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#   'alias': 'my-pie-pizzeria-romana-new-york-2',
#   'name': 'My Pie Pizzeria Romana',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vo36uaolTTa5aREAcddJnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 666,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '690 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#   'phone': '+12123171850',
#   'display_phone': '(212) 317-1850',
#   'distance': 6505.9564779774955},
#  {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#   'alias': 'patsys-pizzeria-brooklyn-2',
#   'name': "Patsy's Pizzeria",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 474,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '450 Dean St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#   'phone': '+17186222268',
#   'display_phone': '(718) 622-2268',
#   'distance': 3034.9893998767334},
#  {'id': 'ynQ8NJB7SEAIkuUxopHPvA',
#   'alias': 'ignazios-brooklyn',
#   'name': "Ignazio's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8X6uFKW7BksKs7H8GYsQxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ignazios-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 441,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.7032251, 'longitude': -73.993782},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4 Water St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4 Water St', 'Brooklyn, NY 11201']},
#   'phone': '+17185222100',
#   'display_phone': '(718) 522-2100',
#   'distance': 250.55975929710243},
#  {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#   'alias': 'artichoke-basilles-pizza-new-york-2',
#   'name': "Artichoke Basille's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_-CRJ_e43JJIuN_Og/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 3803,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7321124557704,
#    'longitude': -73.9839056828882},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '321 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['321 E 14th St', 'New York, NY 10003']},
#   'phone': '+12122282004',
#   'display_phone': '(212) 228-2004',
#   'distance': 3091.822113723405},
#  {'id': 'YuzOnNDfRKixNJiaVy5Baw',
#   'alias': 'robertas-pizza-new-york-2',
#   'name': "Roberta's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DfRh3ueUr2FONIMGoitPMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-pizza-new-york-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 181,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7545170712701,
#    'longitude': -73.9765970005763},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '230 Park Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10169',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['230 Park Ave', 'New York, NY 10169']},
#   'phone': '+16467470820',
#   'display_phone': '(646) 747-0820',
#   'distance': 5656.648409458703},
#  {'id': '7qYeyW9_dxnbaBCFUXGk_A',
#   'alias': 'stage-door-pizza-new-york',
#   'name': 'Stage Door Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G_R4NqV4mPa5ffR7kmuB9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/stage-door-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 226,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7120047333763,
#    'longitude': -74.0096561511938},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '26 Vesey St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10007',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26 Vesey St', 'New York, NY 10007']},
#   'phone': '+12125666222',
#   'display_phone': '(212) 566-6222',
#   'distance': 1486.2421351984565},
#  {'id': '2xQmBB6w-W6lxiex80fA9A',
#   'alias': 'luigis-pizzeria-brooklyn-4',
#   'name': "Luigi's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QgrEW-SMfez8OkMHlgg-Rw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 231,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '326 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#   'phone': '+17187832430',
#   'display_phone': '(718) 783-2430',
#   'distance': 3001.8318150390764},
#  {'id': '58YvTYsyxNyGixTAZiMHcg',
#   'alias': 'williamsburg-pizza-new-york-3',
#   'name': 'Williamsburg Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bqgarjs0DUMBkSoPDdPtHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/williamsburg-pizza-new-york-3?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 188,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71822, 'longitude': -73.99123},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '277 Broome St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['277 Broome St', 'New York, NY 10002']},
#   'phone': '+12122264455',
#   'display_phone': '(212) 226-4455',
#   'distance': 1448.6190383319204},
#  {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#   'alias': 'l-and-b-spumoni-gardens-brooklyn',
#   'name': 'L & B Spumoni Gardens',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 3421,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '2725 86th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11223',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#   'phone': '+17184491230',
#   'display_phone': '(718) 449-1230',
#   'distance': 12361.163422806636},
#  {'id': 'kVrTff8uDMSBAaceBwQ7dg',
#   'alias': 'saluggis-new-york',
#   'name': "Saluggi's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P_NI4AhmWBAi4c33PViGMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/saluggis-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 542,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.720104, 'longitude': -74.003578},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '325 Church St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['325 Church St', 'New York, NY 10013']},
#   'phone': '+12122267900',
#   'display_phone': '(212) 226-7900',
#   'distance': 1808.5885826304711},
#  {'id': 'uEKiv6WEPg9dWj10HCur5A',
#   'alias': 'table-87-coal-oven-pizza-brooklyn-5',
#   'name': 'Table 87 Coal Oven Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P-SRieRAoqpG_o43B8TY8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/table-87-coal-oven-pizza-brooklyn-5?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 243,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.691219329834, 'longitude': -73.9973449707031},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '87 Atlantic Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['87 Atlantic Ave', 'Brooklyn, NY 11201']},
#   'phone': '+17187979300',
#   'display_phone': '(718) 797-9300',
#   'distance': 1602.5908124268826},
#  {'id': 'SpyQHasbnU5YkOR6PI4sNQ',
#   'alias': 'margherita-nyc-new-york',
#   'name': 'Margherita NYC',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOUXE4GPpJ-yDw3CQcSysg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/margherita-nyc-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 273,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7189865112305,
#    'longitude': -73.9969329833984},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '197 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['197 Grand St', 'New York, NY 10013']},
#   'phone': '+12122268391',
#   'display_phone': '(212) 226-8391',
#   'distance': 1531.530627996726},
#  {'id': 'MphfKkYFEe0BDQ6hZ0A5fA',
#   'alias': 'gelso-and-grand-new-york',
#   'name': 'Gelso & Grand',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WwDSyTftSPcDhS45Jyu5xA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 736,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7194089547259,
#    'longitude': -73.9973777877722},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '186 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['186 Grand St', 'New York, NY 10013']},
#   'phone': '+12122261600',
#   'display_phone': '(212) 226-1600',
#   'distance': 1574.3490321455226},
#  {'id': '0ROpM3UcZhprN6dhwK2Hsw',
#   'alias': 'joe-and-pats-pizzeria-new-york',
#   'name': "Joe & Pat's Pizzeria",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/54SAnkVg790vhVkC5sT1IQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joe-and-pats-pizzeria-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 107,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72892, 'longitude': -73.98411},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '168 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['168 1st Ave', 'New York, NY 10009']},
#   'phone': '+12126774992',
#   'display_phone': '(212) 677-4992',
#   'distance': 2747.4328138602286},
#  {'id': '3VJwpmmeoPlCN3J5p5miEQ',
#   'alias': 'brooklyns-homeslice-pizzeria-brooklyn',
#   'name': "Brooklyn's Homeslice Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9ImrGJAQShKpXYR3XHor9Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 97,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.680702, 'longitude': -73.967455},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '567 Vanderbilt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#   'phone': '+17183999000',
#   'display_phone': '(718) 399-9000',
#   'distance': 3562.2182094944847},
#  {'id': 'c3D2ckzacnPtdGIM8tb-_w',
#   'alias': 'b-side-pizza-and-wine-bar-new-york',
#   'name': 'B Side Pizza & Wine Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m_5goJPoabzTHCyQ2qAVGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/b-side-pizza-and-wine-bar-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 1005,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76394, 'longitude': -73.9883399},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '370 W 51st St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['370 W 51st St', 'New York, NY 10019']},
#   'phone': '+16466797225',
#   'display_phone': '(646) 679-7225',
#   'distance': 6519.850090048231},
#  {'id': 'PBsVApRd0dHVjWgiGZgcRQ',
#   'alias': 'louie-and-ernies-pizza-bronx-2',
#   'name': "Louie & Ernie's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R-p0ELcXiEwWbkIVUyvRkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/louie-and-ernies-pizza-bronx-2?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 256,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.838288, 'longitude': -73.828563},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1300 Crosby Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10461',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1300 Crosby Ave', 'Bronx, NY 10461']},
#   'phone': '+17188296230',
#   'display_phone': '(718) 829-6230',
#   'distance': 20314.878649813818},
#  {'id': '89qVlmj0Jpf2MG63ImwQig',
#   'alias': 'famous-calabria-new-york',
#   'name': 'Famous Calabria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tCJGl88Fv5S2gWgVgCtNDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/famous-calabria-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 74,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.711942, 'longitude': -73.999349},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '27 Saint James Pl',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Saint James Pl', 'New York, NY 10038']},
#   'phone': '+12122330009',
#   'display_phone': '(212) 233-0009',
#   'distance': 838.7697713099058},
#  {'id': '4h4Tuuc56YPO6lWfZ1bdSQ',
#   'alias': 'joes-pizza-new-york-152',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pnB2x6JVY5Ce0flZQhIqCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 50,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7101297729083,
#    'longitude': -74.0077206864953},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '124 Fulton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['124 Fulton St', 'New York, NY 10038']},
#   'phone': '+12122670860',
#   'display_phone': '(212) 267-0860',
#   'distance': 1245.9428626945232},
#  {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#   'alias': 'bakers-pizza-new-york',
#   'name': "Baker's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3TbUAZcHe7PQ278pONEU0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 180,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7294399, 'longitude': -73.98125},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '201 Avenue A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['201 Avenue A', 'New York, NY 10009']},
#   'phone': '+12127777477',
#   'display_phone': '(212) 777-7477',
#   'distance': 2883.8861591779555},
#  {'id': 'iSr36HYfNRXvMhjhvP77vA',
#   'alias': 'archies-bar-and-pizza-brooklyn',
#   'name': "Archie's Bar & Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ol7C48_00aZzHXGAbv4Qgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/archies-bar-and-pizza-brooklyn?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 276,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.699705, 'longitude': -73.928512},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '128 Central Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 Central Ave', 'Brooklyn, NY 11221']},
#   'phone': '+13479152244',
#   'display_phone': '(347) 915-2244',
#   'distance': 5582.687406178507},
#  {'id': '1uOB_tWZwvI0_HakXfu5Jg',
#   'alias': 'nicks-pizza-new-york',
#   'name': "Nick's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/B7wgdiOEVw6yU4RWbAEKyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nicks-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 502,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.78272, 'longitude': -73.94781},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1814 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1814 2nd Ave', 'New York, NY 10128']},
#   'phone': '+12129875700',
#   'display_phone': '(212) 987-5700',
#   'distance': 9442.562366002065},
#  {'id': 'SSCbDzX4e11kpojBWeFWfQ',
#   'alias': 'clinton-square-pizza-new-york',
#   'name': 'Clinton Square Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7xKrCG_XHaAQlXivcpqKeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/clinton-square-pizza-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 71,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71395, 'longitude': -73.98724},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '201 Clinton St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['201 Clinton St', 'New York, NY 10002']},
#   'phone': '+16466784294',
#   'display_phone': '(646) 678-4294',
#   'distance': 1117.9194767487822},
#  {'id': 'xeC9vn3dxVVzAMR_aFwfXg',
#   'alias': 'il-brigante-new-york',
#   'name': 'IL Brigante',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qk5GDAERuUt9cd25PZhQTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/il-brigante-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 353,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.707492, 'longitude': -74.002571},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '214 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Front St', 'New York, NY 10038']},
#   'phone': '+12122850222',
#   'display_phone': '(212) 285-0222',
#   'distance': 738.248263617683},
#  {'id': 'm3PS0tIaa0ChcP8Y5S-DrQ',
#   'alias': 'mamas-too-new-york',
#   'name': "MAMA'S TOO!",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NTpvPQSoxumdAuc6szUSyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mamas-too-new-york?adjust_creative=cUT1nApSyYJfaEj7aoOYqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cUT1nApSyYJfaEj7aoOYqg',
#   'review_count': 212,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.80084, 'longitude': -73.96766},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2750 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2750 Broadway', 'New York, NY 10025']},
#   'phone': '+12125107256',
#   'display_phone': '(212) 510-7256',
#   'distance': 10842.47369179763}]

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
